# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### 1.matplotlib

# %%
from matplotlib import pyplot as plt
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# x轴：years； y轴：gdp
plt.plot(years,gdp,color='green',marker='o',linestyle='solid')

# 添加标题
plt.title("Nominal GDP")

# 为y轴添加标签
plt.ylabel("Billions of $")
plt.show()

# %% [markdown]
# ### 2.条形图
# #### 2.1 普通条形图

# %%
movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]

# 以[0,1,2,3,4]作为x轴坐标，[num_oscars]作为高度
plt.bar(range(len(movies)),num_oscars)

plt.title("My favorite Movies") # 添加标题
plt.ylabel("# of Academy Awards") # 添加y轴标签

# 在x轴上的条形中心加上电影名字作为x轴标签
plt.xticks(range(len(movies)),movies)

plt.show()

# %% [markdown]
# #### 2.2 直方图

# %%
from collections import Counter
grades = [83, 95, 91, 87, 70, 0, 85, 82, 100, 67, 73, 77, 0]

# 将数据按照0~100每10个数为一个分箱，并统计grades的值出现在每个箱中的次数
histogram = Counter(min(grade // 10 * 10 ,90) for grade in grades) 

plt.bar([x + 5 for x in histogram.keys()], # 中心位置
        histogram.values(), # 高度为出现频次
        10, # 每个条形的宽度为10
        edgecolor = (0,0,0))  # 边框设置为黑色

plt.axis([-5, 105, 0, 5]) # x轴取值范围为-5~105, y轴取值范围为0~5

plt.xticks([10 * i for i in range(11)]) # x轴标签为0,10，...100
plt.xlabel("Decile")
plt.ylabel("# of Students")
plt.title("Distribution of Exam 1 Grades") 
plt.show()

# %% [markdown]
# #### 2.3 x、y轴刻度问题

# %%
mentions = [500, 505]
years = [2017, 2018]

plt.bar(years, mentions, 0.8)
plt.xticks(years)
plt.ylabel("# of times I heard someone say 'data science'")

# 用于确保坐标轴的标签显示实际的坐标值，而不是使用偏移
plt.ticklabel_format(useOffset=False)

plt.axis([2016.5, 2018.5, 0, 550])
plt.title("Not So Huge Anymore")
plt.show()

# %% [markdown]
# ### 3.线图

# %%
variance = [1, 2, 4, 8, 16, 32, 64, 128, 256] # 方差
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1] # 偏差平方
total_error = [x + y for x, y in zip(variance,bias_squared)] # 总误差
xs = [i for i, _ in enumerate(variance)] # 返回一个包含索引值的列表
xs
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
# 可以多次调用plt.plot
# 以便在同一个图上显示多个序列
plt.plot(xs, variance, 'g-', label='variance')
plt.plot(xs, bias_squared, 'r-.', label='bias^2')
plt.plot(xs, total_error, 'b:', label='total error')

plt.legend(loc=9) # 将图标置于顶部中央
plt.xlabel("model complexity")
plt.xticks([]) # 情况x轴上刻度标签
plt.title("The Bias-Variance Tradeoff")
plt.show()

# %% [markdown]
# ### 4.散点图

# %%
friends = [ 70, 65, 72, 63, 71, 64, 60, 64, 67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

plt.scatter(friends, minutes)

# 给每个点加上标签
for label, friend_count, minute_count in zip(labels, friends, minutes):
    # annotate主要用于给图标加注释
    plt.annotate(label, # 要显示的文字
                xy = (friend_count, minute_count),# 包含2个值的元组，表示要注释的点的位置
                 xytext = (5, -5), # 文本位置相对于xy坐标的偏移
                 textcoords = 'offset points') # 以偏移点的方式解释的

plt.title("Daily Minutes vs. Number of Friends")
plt.xlabel("# of friends")
plt.ylabel("daily minutes spent on the site")
plt.show()

# %% [markdown]
# ### 延伸

# %% [markdown]
# - matplotlib Gallery 将为你解读 matplotlib 的各种功能（以及如何操作）。
# - seaborn 基于 matplotlib 构建，可让你轻松地制作更漂亮（也更复杂）的可视化。
# - Altair 是一个较新的 Python 库，用于创建声明式可视化。
# - D3.js 是一个 JavaScript 库，用于为 Web 生成复杂的交互式可视化。虽然它不能在
#   Python 中使用，但它用途广泛，值得你去学习了解。
# - Bokeh 是一个库，用于将 D3 风格的可视化引入 Python 中。
